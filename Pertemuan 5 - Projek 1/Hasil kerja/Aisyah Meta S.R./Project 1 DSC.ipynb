# %%
import pandas as pd
import mysql.connector as mysql

# %%
koneksi = mysql.connect(host = "localhost",
                       database = "project_dsc",
                       user = "root",
                       password = "")
cursor = koneksi.cursor()

# %% [markdown]
# # Operasi CRUD

# %% [markdown]
# ## Create

# %%
cursor.execute("""INSERT INTO employees (employeeNumber, lastName, firstName, extension, email, officeCode, reportsTo, jobTitle) VALUES ("1804","Denn","Jhoana","x103","jhn@classicmodelcars.com","4","1102.0","sale rep")""")

# %% [markdown]
# ## Read

# %%
cursor.execute("SELECT * FROM employees")
employees = cursor.fetchall()

# %%
data_employees  = pd.DataFrame(columns = ["Employees Number","Last Name","First Name","Extension",
                                           "Email","Office Code","Reports To","Job Title"],
                            data = employees)


data_employees
# Out:
#     Employees Number  Last Name First Name Extension  \
# 0               1002     Murphy      Diane     x5800
# 1               1056  Patterson       Mary     x4611
# 2               1076   Firrelli       Jeff     x9273
# 3               1088  Patterson    William     x4871
# 4               1102     Bondur     Gerard     x5408
# 5               1143        Bow    Anthony     x5428
# 6               1165   Jennings     Leslie     x3291
# 7               1166   Thompson     Leslie     x4065
# 8               1188   Firrelli      Julie     x2173
# 9               1216  Patterson      Steve     x4334
# 10              1286      Tseng   Foon Yue     x2248
# 11              1323     Vanauf     George     x4102
# 12              1337     Bondur       Loui     x6493
# 13              1370  Hernandez     Gerard     x2028
# 14              1401   Castillo     Pamela     x2759
# 15              1501       Bott      Larry     x2311
# 16              1504      Jones      Barry      x102
# ...

# %% [markdown]
# ## Delete

# %%
cursor.execute("DELETE FROM employees WHERE employeeNumber=1804")

# %%
cursor.execute("SELECT * FROM employees")
employees = cursor.fetchall()

# %%
data_employees  = pd.DataFrame(columns = ["Employees Number","Last Name","First Name","Extension",
                                           "Email","Office Code","Reports To","Job Title"],
                            data = employees)

data_employees
# Out:
#     Employees Number  Last Name First Name Extension  \
# 0               1002     Murphy      Diane     x5800
# 1               1056  Patterson       Mary     x4611
# 2               1076   Firrelli       Jeff     x9273
# 3               1088  Patterson    William     x4871
# 4               1102     Bondur     Gerard     x5408
# 5               1143        Bow    Anthony     x5428
# 6               1165   Jennings     Leslie     x3291
# 7               1166   Thompson     Leslie     x4065
# 8               1188   Firrelli      Julie     x2173
# 9               1216  Patterson      Steve     x4334
# 10              1286      Tseng   Foon Yue     x2248
# 11              1323     Vanauf     George     x4102
# 12              1337     Bondur       Loui     x6493
# 13              1370  Hernandez     Gerard     x2028
# 14              1401   Castillo     Pamela     x2759
# 15              1501       Bott      Larry     x2311
# 16              1504      Jones      Barry      x102
# ...

# %% [markdown]
# ## Update

# %%
cursor.execute("UPDATE employees SET lastName='Oey',officeCode='7' WHERE employeeNumber=1702 ")

# %%
cursor.execute("SELECT * FROM employees")
employees = cursor.fetchall()
data_employees  = pd.DataFrame(columns = ["Employees Number","Last Name","First Name","Extension",
                                           "Email","Office Code","Reports To","Job Title"],
                            data = employees)

data_employees
# Out:
#     Employees Number  Last Name First Name Extension  \
# 0               1002     Murphy      Diane     x5800
# 1               1056  Patterson       Mary     x4611
# 2               1076   Firrelli       Jeff     x9273
# 3               1088  Patterson    William     x4871
# 4               1102     Bondur     Gerard     x5408
# 5               1143        Bow    Anthony     x5428
# 6               1165   Jennings     Leslie     x3291
# 7               1166   Thompson     Leslie     x4065
# 8               1188   Firrelli      Julie     x2173
# 9               1216  Patterson      Steve     x4334
# 10              1286      Tseng   Foon Yue     x2248
# 11              1323     Vanauf     George     x4102
# 12              1337     Bondur       Loui     x6493
# 13              1370  Hernandez     Gerard     x2028
# 14              1401   Castillo     Pamela     x2759
# 15              1501       Bott      Larry     x2311
# 16              1504      Jones      Barry      x102
# ...

# %% [markdown]
# # Memasukkan data yang belum dipraproses ke dalam Data Frame Baru

# %%
data_employees
# Out:
#     Employees Number  Last Name First Name Extension  \
# 0               1002     Murphy      Diane     x5800
# 1               1056  Patterson       Mary     x4611
# 2               1076   Firrelli       Jeff     x9273
# 3               1088  Patterson    William     x4871
# 4               1102     Bondur     Gerard     x5408
# 5               1143        Bow    Anthony     x5428
# 6               1165   Jennings     Leslie     x3291
# 7               1166   Thompson     Leslie     x4065
# 8               1188   Firrelli      Julie     x2173
# 9               1216  Patterson      Steve     x4334
# 10              1286      Tseng   Foon Yue     x2248
# 11              1323     Vanauf     George     x4102
# 12              1337     Bondur       Loui     x6493
# 13              1370  Hernandez     Gerard     x2028
# 14              1401   Castillo     Pamela     x2759
# 15              1501       Bott      Larry     x2311
# 16              1504      Jones      Barry      x102
# ...

# %%
data_employees.describe()
# Out:
#        Employees Number   Reports To
# count         23.000000    22.000000
# mean        1335.391304  1117.409091
# std          223.565475   120.173549
# min         1002.000000  1002.000000
# 25%         1154.000000  1064.000000
# 50%         1323.000000  1102.000000
# 75%         1557.500000  1143.000000
# max         1702.000000  1621.000000

# %%
data_employees["Office Code"].value_counts()
# Out:
# 1    6
# 6    4
# 4    4
# 7    3
# 3    2
# 5    2
# 2    2
# Name: Office Code, dtype: int64

# %%
data_employees["Job Title"].value_counts()
# Out:
# Sales Rep               11
# sls rep                  3
# sale rep                 3
# Sales Manager (NA)       1
# VP Sales                 1
# Sales Manager (APAC)     1
# Sale Manager (EMEA)      1
# VP Marketing             1
# President                1
# Name: Job Title, dtype: int64

# %%
data_employees["Reports To"].value_counts()
# Out:
# 1102.0    6
# 1143.0    6
# 1056.0    4
# 1088.0    3
# 1002.0    2
# 1621.0    1
# Name: Reports To, dtype: int64

# %% [markdown]
# ## Data Inkonsisten

# %%
data_employees["Job Title"]=data_employees["Job Title"].replace(["sale rep","sls rep"],"Sales Rep")
data_employees["Job Title"]=data_employees["Job Title"].replace("Sale Manager (EMEA)","Sale Manager (EMEA)")

# %%
data_employees
# Out:
#     Employees Number  Last Name First Name Extension  \
# 0               1002     Murphy      Diane     x5800
# 1               1056  Patterson       Mary     x4611
# 2               1076   Firrelli       Jeff     x9273
# 3               1088  Patterson    William     x4871
# 4               1102     Bondur     Gerard     x5408
# 5               1143        Bow    Anthony     x5428
# 6               1165   Jennings     Leslie     x3291
# 7               1166   Thompson     Leslie     x4065
# 8               1188   Firrelli      Julie     x2173
# 9               1216  Patterson      Steve     x4334
# 10              1286      Tseng   Foon Yue     x2248
# 11              1323     Vanauf     George     x4102
# 12              1337     Bondur       Loui     x6493
# 13              1370  Hernandez     Gerard     x2028
# 14              1401   Castillo     Pamela     x2759
# 15              1501       Bott      Larry     x2311
# 16              1504      Jones      Barry      x102
# ...

# %% [markdown]
# # Praproses Data Frame

# %% [markdown]
# ## Membersihkan Data yang Memiliki Nilai Kosong/Hilang

# %%
import numpy as np

# %%
data_employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employees Number  23 non-null     int64
#  1   Last Name         23 non-null     object
#  2   First Name        23 non-null     object
#  3   Extension         23 non-null     object
#  4   Email             23 non-null     object
#  5   Office Code       23 non-null     object
#  6   Reports To        22 non-null     float64
#  7   Job Title         23 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.6+ KB

# %%
np.sum(data_employees.isnull())
# Out:
# Employees Number    0
# Last Name           0
# First Name          0
# Extension           0
# Email               0
# Office Code         0
# Reports To          1
# Job Title           0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
from scipy.stats import mode

# %%
data_employees["Reports To"].mode()
# Out:
# 0    1102.0
# 1    1143.0
# dtype: float64

# %%
data_employees["Reports To"]=data_employees["Reports To"].fillna(data_employees["Reports To"].mode()[0])

# %%
data_employees
# Out:
#     Employees Number  Last Name First Name Extension  \
# 0               1002     Murphy      Diane     x5800
# 1               1056  Patterson       Mary     x4611
# 2               1076   Firrelli       Jeff     x9273
# 3               1088  Patterson    William     x4871
# 4               1102     Bondur     Gerard     x5408
# 5               1143        Bow    Anthony     x5428
# 6               1165   Jennings     Leslie     x3291
# 7               1166   Thompson     Leslie     x4065
# 8               1188   Firrelli      Julie     x2173
# 9               1216  Patterson      Steve     x4334
# 10              1286      Tseng   Foon Yue     x2248
# 11              1323     Vanauf     George     x4102
# 12              1337     Bondur       Loui     x6493
# 13              1370  Hernandez     Gerard     x2028
# 14              1401   Castillo     Pamela     x2759
# 15              1501       Bott      Larry     x2311
# 16              1504      Jones      Barry      x102
# ...

# %%
data_employees.isnull().sum()
# Out:
# Employees Number    0
# Last Name           0
# First Name          0
# Extension           0
# Email               0
# Office Code         0
# Reports To          0
# Job Title           0
# dtype: int64

# %% [markdown]
# ## Mendeteksi Outlier Pada Data

# %%
data_employees.boxplot(["Reports To"])

# %%
data_employees.boxplot(["Employees Number"])

# %%
data_employees._get_numeric_data()
# Out:
#     Employees Number  Reports To
# 0               1002      1102.0
# 1               1056      1002.0
# 2               1076      1002.0
# 3               1088      1056.0
# 4               1102      1056.0
# 5               1143      1056.0
# 6               1165      1143.0
# 7               1166      1143.0
# 8               1188      1143.0
# 9               1216      1143.0
# 10              1286      1143.0
# 11              1323      1143.0
# 12              1337      1102.0
# 13              1370      1102.0
# 14              1401      1102.0
# 15              1501      1102.0
# 16              1504      1102.0
# 17              1611      1088.0
# 18              1612      1088.0
# 19              1619      1088.0
# 20              1621      1056.0
# 21              1625      1621.0
# 22              1702      1102.0

# %% [markdown]
# ## Melakukan Normalisasi Nilai Pada Data

# %%
from scipy import stats

hasil_zscore = np.abs(stats.zscore(data_employees._get_numeric_data()))
print(hasil_zscore)
# Out:
# [[1.52476217 0.12830828]
#  [1.27779365 0.99883645]
#  [1.18632383 0.99883645]
#  [1.13144193 0.52875124]
#  [1.06741306 0.52875124]
#  [0.87989992 0.52875124]
#  [0.77928312 0.22860827]
#  [0.77470963 0.22860827]
#  [0.67409282 0.22860827]
#  [0.54603507 0.22860827]
#  [0.22589069 0.22860827]
#  [0.05667152 0.22860827]
#  [0.00735736 0.12830828]
#  [0.15828256 0.12830828]
#  [0.30006079 0.12830828]
#  [0.7574099  0.12830828]
#  [0.77113037 0.12830828]
#  [1.26049392 0.25018223]
#  [1.26506741 0.25018223]
#  [1.29708185 0.25018223]
#  [1.30622883 0.52875124]
#  [1.3245228  4.38973291]
#  [1.67668161 0.12830828]]

# %%
hasil_zscore.shape
# Out:
# (23, 2)

# %%
outlier = data_employees[(hasil_zscore < 3).all(axis=1)]
print(data_employees.shape)
# Out:
# (23, 8)

# %%
outlier
# Out:
#     Employees Number  Last Name First Name Extension  \
# 0               1002     Murphy      Diane     x5800
# 1               1056  Patterson       Mary     x4611
# 2               1076   Firrelli       Jeff     x9273
# 3               1088  Patterson    William     x4871
# 4               1102     Bondur     Gerard     x5408
# 5               1143        Bow    Anthony     x5428
# 6               1165   Jennings     Leslie     x3291
# 7               1166   Thompson     Leslie     x4065
# 8               1188   Firrelli      Julie     x2173
# 9               1216  Patterson      Steve     x4334
# 10              1286      Tseng   Foon Yue     x2248
# 11              1323     Vanauf     George     x4102
# 12              1337     Bondur       Loui     x6493
# 13              1370  Hernandez     Gerard     x2028
# 14              1401   Castillo     Pamela     x2759
# 15              1501       Bott      Larry     x2311
# 16              1504      Jones      Barry      x102
# ...

# %%
import seaborn as sns
sns.set(style="whitegrid")

# %%
data_baru = pd.DataFrame([])

data_baru["Keterangan"] = ["tidak ada outlier","outlier"]
data_baru["jumlah observasi"] = [22, 23-22]

data_baru
# Out:
#           Keterangan  jumlah observasi
# 0  tidak ada outlier                22
# 1            outlier                 1

# %%
plot=sns.barplot(x="Keterangan",y="jumlah observasi",data=data_baru)

# %% [markdown]
# ## Melakukan Transformasi Data (Label encoding, Scalling, Binning)

# %%
data_employees.dtypes
# Out:
# Employees Number      int64
# Last Name            object
# First Name           object
# Extension            object
# Email                object
# Office Code          object
# Reports To          float64
# Job Title            object
# dtype: object

# %%
#Label Encoding
from sklearn import preprocessing
kategori = ["Last Name",
            "First Name",
            "Extension",
            "Email",
            "Office Code",
            "Job Title"]

le = preprocessing.LabelEncoder()
for feature in kategori:
    if feature in data_employees.columns.values:
        data_employees[feature] = le.fit_transform(data_employees[feature])

# %%
data_employees
# Out:
#     Employees Number  Last Name  First Name  Extension  Email  Office Code  \
# 0               1002         12           3         17      3            0
# 1               1056         15          14         13     15            0
# 2               1076          4           7         19      8            0
# 3               1088         15          19         14     20            5
# 4               1102          0           6         15      5            3
# 5               1143          2           1         16      0            0
# 6               1165          7          10          9     11            0
# 7               1166         16          10         10     12            0
# 8               1188          4           8          4      8            1
# 9               1216         15          17         12     18            1
# 10              1286         17           4          5      4            2
# ...

# %%
data_employees.dtypes
# Out:
# Employees Number      int64
# Last Name             int32
# First Name            int32
# Extension             int32
# Email                 int32
# Office Code           int32
# Reports To          float64
# Job Title             int32
# dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Binning
cursor.execute("SELECT SUM(creditlimit) AS total_credit_handle,employeeNumber,firstName,lastName FROM employees a,customers b WHERE a.employeeNumber=b.salesRepEmployeeNumber GROUP BY employeeNumber")
employees = cursor.fetchall()
data_employees_binning  = pd.DataFrame(columns = ["Total Credit Handle","Employee Number","First Name","Last Name"],
                            data = employees)


data_employees_binning
# Out:
#    Total Credit Handle  Employee Number First Name  Last Name
# 0            602600.00             1165     Leslie   Jennings
# 1            391600.00             1166     Leslie   Thompson
# 2            443500.00             1188      Julie   Firrelli
# 3            489200.00             1216      Steve  Patterson
# 4            466300.00             1286   Foon Yue      Tseng
# 5            647100.00             1323     George     Vanauf
# 6            517400.00             1337       Loui     Bondur
# 7            642500.00             1370     Gerard  Hernandez
# 8            813400.00             1401     Pamela   Castillo
# 9            729500.00             1501      Larry       Bott
# 10           769600.00             1504      Barry      Jones
# 11           430300.00             1611       Andy     Fixter
# 12           460400.00             1612      Peter      Marsh
# 13           419500.00             1621       Mami      Nishi
# ...

# %%
data_employees_binning.dtypes
# Out:
# Total Credit Handle    object
# Employee Number         int64
# First Name             object
# Last Name              object
# dtype: object

# %%
pd.to_numeric(data_employees_binning["Total Credit Handle"])
# Out:
# 0     602600.0
# 1     391600.0
# 2     443500.0
# 3     489200.0
# 4     466300.0
# 5     647100.0
# 6     517400.0
# 7     642500.0
# 8     813400.0
# 9     729500.0
# 10    769600.0
# 11    430300.0
# 12    460400.0
# 13    419500.0
# 14    431500.0
# Name: Total Credit Handle, dtype: float64

# %%
pd.qcut(data_employees_binning["Total Credit Handle"], q=2).value_counts()
# Out:
# (391599.999, 489200.0]    8
# (489200.0, 813400.0]      7
# Name: Total Credit Handle, dtype: int64

# %%
pd.qcut(data_employees_binning["Total Credit Handle"], q=2).value_counts().plot(kind='bar')

# %%
label = ['Tidak Dapat Bonus','Dapat Bonus']

label_binning = pd.qcut(data_employees_binning['Total Credit Handle'],
                        q = [0,0.5,1],
                        labels = label)

label_binning
# Out:
# 0           Dapat Bonus
# 1     Tidak Dapat Bonus
# 2     Tidak Dapat Bonus
# 3     Tidak Dapat Bonus
# 4     Tidak Dapat Bonus
# 5           Dapat Bonus
# 6           Dapat Bonus
# 7           Dapat Bonus
# 8           Dapat Bonus
# 9           Dapat Bonus
# 10          Dapat Bonus
# 11    Tidak Dapat Bonus
# 12    Tidak Dapat Bonus
# 13    Tidak Dapat Bonus
# 14    Tidak Dapat Bonus
# Name: Total Credit Handle, dtype: category
# Categories (2, object): [Tidak Dapat Bonus < Dapat Bonus]

# %%
label_binning.value_counts().plot(kind='barh')

# %%
#Scalling
data_employees.describe()
# Out:
#        Employees Number  Last Name  First Name  Extension      Email  \
# count         23.000000  23.000000   23.000000  23.000000  23.000000
# mean        1335.391304   8.913043    9.826087   8.347826  10.391304
# std          223.565475   5.830274    5.974584   6.285689   6.365669
# min         1002.000000   0.000000    0.000000   0.000000   0.000000
# 25%         1154.000000   4.000000    5.500000   2.500000   5.500000
# 50%         1323.000000   9.000000   10.000000   8.000000  10.000000
# 75%         1557.500000  14.500000   14.500000  13.500000  15.500000
# max         1702.000000  18.000000   20.000000  19.000000  21.000000
#
#        Office Code   Reports To  Job Title
# count    23.000000    23.000000  23.000000
# mean      2.782609  1116.739130   3.695652
# std       2.214755   117.454524   1.222322
# min       0.000000  1002.000000   0.000000
# 25%       0.500000  1072.000000   4.000000
# 50%       3.000000  1102.000000   4.000000
# ...

# %%
outlier.boxplot(['Employees Number','Reports To'])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(data_employees[['Employees Number']])
data_employees['Employees Number'] = scaler.transform(data_employees[['Employees Number']])

# %%
data_employees.boxplot(['Employees Number'])

# %%
data_employees['Employees Number'].describe()
# Out:
# count    23.000000
# mean      0.476273
# std       0.319379
# min       0.000000
# 25%       0.217143
# 50%       0.458571
# 75%       0.793571
# max       1.000000
# Name: Employees Number, dtype: float64

# %%
scaler.fit(data_employees[['Reports To']])
data_employees['Reports To'] = scaler.transform(data_employees[['Reports To']])

# %%
data_employees.boxplot(['Reports To'])

# %%
data_employees.boxplot(['Employees Number','Reports To'])

# %%
data_employees
# Out:
#     Employees Number  Last Name  First Name  Extension  Email  Office Code  \
# 0           0.000000         12           3         17      3            0
# 1           0.077143         15          14         13     15            0
# 2           0.105714          4           7         19      8            0
# 3           0.122857         15          19         14     20            5
# 4           0.142857          0           6         15      5            3
# 5           0.201429          2           1         16      0            0
# 6           0.232857          7          10          9     11            0
# 7           0.234286         16          10         10     12            0
# 8           0.265714          4           8          4      8            1
# 9           0.305714         15          17         12     18            1
# 10          0.405714         17           4          5      4            2
# ...

# %% [markdown]
# ## Feature Selection/Extraction

# %%
#Feature Selection
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
bmsx = np.array([data_employees["Last Name"],
                data_employees["First Name"],
                data_employees["Extension"],
                data_employees['Email'],
                data_employees["Office Code"]])
bmsx.shape
# Out:
# (5, 23)

# %%
bmsx
# Out:
# array([[12, 15,  4, 15,  0,  2,  7, 16,  4, 15, 17, 18,  0,  6,  3,  1,
#          8,  5, 11, 10, 13,  9, 14],
#        [ 3, 14,  7, 19,  6,  1, 10, 10,  8, 17,  4,  5, 11,  6, 15,  9,
#          2,  0, 16, 18, 12, 20, 13],
#        [17, 13, 19, 14, 15, 16,  9, 10,  4, 12,  5, 11, 18,  3,  8,  6,
#          1,  0,  1,  2,  0,  1,  7],
#        [ 3, 15,  8, 20,  5,  0, 11, 12,  8, 18,  4,  7,  9,  6, 16, 10,
#          2,  1, 17, 19, 14, 21, 13],
#        [ 0,  0,  0,  5,  3,  0,  0,  0,  1,  1,  2,  2,  3,  3,  3,  6,
#          6,  5,  5,  5,  4,  4,  6]])

# %%
bmsxt=bmsx.transpose()
bmsxt.shape
# Out:
# (23, 5)

# %%
bms_std=StandardScaler().fit_transform(bmsxt)
bms_std
# Out:
# array([[ 0.54136992, -1.16819874,  1.40742401, -1.18721568, -1.28463303],
#        [ 1.06748999,  0.71431261,  0.75675562,  0.7402639 , -1.28463303],
#        [-0.86161692, -0.48364916,  1.7327582 , -0.38409919, -1.28463303],
#        [ 1.06748999,  1.56999958,  0.91942272,  1.54338039,  1.02369195],
#        [-1.56311035, -0.65478655,  1.08208981, -0.86596909,  0.10036196],
#        [-1.21236363, -1.51047353,  1.24475691, -1.66908558, -1.28463303],
#        [-0.33549685,  0.02976303,  0.10608724,  0.0977707 , -1.28463303],
#        [ 1.24286335,  0.02976303,  0.26875433,  0.258394  , -1.28463303],
#        [-0.86161692, -0.31251176, -0.70724824, -0.38409919, -0.82296804],
#        [ 1.06748999,  1.22772479,  0.59408853,  1.22213379, -0.82296804],
#        [ 1.4182367 , -0.99706134, -0.54458115, -1.02659238, -0.36130304],
#        [ 1.59361006, -0.82592395,  0.43142143, -0.54472249, -0.36130304],
#        [-1.56311035,  0.20090042,  1.5700911 , -0.22347589,  0.10036196],
# ...

# %%
pcafs=PCA(n_components=0.70,whiten=True)
bmsfs_pca=pcafs.fit_transform(bms_std)

# %%
print('Original number of features:', bms_std.shape[1])
print('Reduced numer of features:', bmsfs_pca.shape[1])
# Out:
# Original number of features: 5
# Reduced numer of features: 2

# %%
datafs_pca=pd.DataFrame(bmsfs_pca, columns=["PC1","PC2"])
datafs_pca
# Out:
#          PC1       PC2
# 0   1.347791 -1.023002
# 1  -0.354908 -1.597316
# 2   1.086269 -1.163030
# 3  -1.440274 -0.820603
# 4   1.063378  0.182736
# 5   1.958227 -0.361191
# 6   0.293603 -0.668029
# 7  -0.026700 -1.152908
# 8   0.462019  0.274593
# 9  -0.867244 -1.479158
# 10  0.498952  0.169435
# 11  0.397155 -0.498342
# 12  0.574101 -0.370688
# 13  0.436792  0.889824
# 14 -0.537236 -0.041899
# 15 -0.043333  1.331298
# 16  0.544547  1.962787
# 17  0.898739  2.031661
# 18 -1.327361  0.616210
# 19 -1.522536  0.439275
# 20 -0.875067  0.615408
# 21 -1.685405  0.187053
# 22 -0.881506  0.475887

# %%
#Feature Extraction
from sklearn import decomposition

# %%
pcafe=decomposition.PCA(n_components=3)
bmsfe_pca=pcafe.fit_transform(bms_std)

# %%
print('Original number of features:', bms_std.shape[1])
print('Reduced numer of features:', bmsfe_pca.shape[1])
# Out:
# Original number of features: 5
# Reduced numer of features: 3

# %%
datafe_pca=pd.DataFrame(bmsfe_pca, columns=["PC1","PC2", "PC3"])
datafe_pca
# Out:
#          PC1       PC2       PC3
# 0   2.094545 -1.255731  0.756368
# 1  -0.551548 -1.960701  0.474708
# 2   1.688124 -1.427616 -0.929262
# 3  -2.238268 -1.007288 -0.291409
# 4   1.652550  0.224308 -1.348760
# 5   3.043197 -0.443361 -0.505057
# 6   0.456276 -0.820003 -0.189137
# 7  -0.041494 -1.415191  1.087624
# 8   0.718004  0.337062 -0.234933
# 9  -1.347746 -1.815662  0.218977
# 10  0.775400  0.207981  1.955259
# 11  0.617201 -0.611714  1.635844
# 12  0.892186 -0.455019 -1.893604
# 13  0.678799  1.092256  0.170243
# 14 -0.834896 -0.051431 -1.335801
# 15 -0.067343  1.634164 -1.208418
# 16  0.846257  2.409315  0.736730
# 17  1.396693  2.493857  0.528822
# 18 -2.062795  0.756395  0.049577
# 19 -2.366109  0.539209 -0.322311
# 20 -1.359905  0.755412  0.765889
# 21 -2.619217  0.229607 -0.527921
# 22 -1.369912  0.584149  0.406573

# %% [markdown]
# ## Visualisasi Data

# %%
import seaborn as sns
sns.set(style="whitegrid")

# %%
sns.set(style="whitegrid")
sns.barplot(x="Job Title",y="Office Code",data=data_employees, ci=None)

# %%
sns.barplot(x="Last Name",y="Total Credit Handle",data=data_employees_binning, ci=None)

# %% [markdown]
# # Tabel Pada Database Hasil Praproses Data

# %%
import pandas as pd
import pymysql

# %%
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="",
                               db="project_dsc"))

# %%
data_employees.to_sql('praprocessing', con = engine, if_exists = 'append', chunksize = 1000)

# %% [markdown]
# # Ekspor Database dan Data Frame

# %%
data_employees.to_csv('C:/Users/Public/data_hasil_ekspor.csv',index=False)

# %%
import pandas as pd
pd.read_csv("C:/Users/Public/data_hasil_ekspor.csv")
# Out:
#     Employees Number  Last Name  First Name  Extension  Email  Office Code  \
# 0           0.000000         12           3         17      3            0
# 1           0.077143         15          14         13     15            0
# 2           0.105714          4           7         19      8            0
# 3           0.122857         15          19         14     20            5
# 4           0.142857          0           6         15      5            3
# 5           0.201429          2           1         16      0            0
# 6           0.232857          7          10          9     11            0
# 7           0.234286         16          10         10     12            0
# 8           0.265714          4           8          4      8            1
# 9           0.305714         15          17         12     18            1
# 10          0.405714         17           4          5      4            2
# ...
